# %%
from ultralytics import YOLO
import torch

# %%
device = ('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)

# !yolo task=detect mode=train model=yolov8m.pt data=/home/heris/data/RAW/YOLO_dataset/data.yaml epochs=30 imgsz=512
# Out:
# cuda:0
# New https://pypi.org/project/ultralytics/8.0.203 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.13 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11163MiB)
# ...
