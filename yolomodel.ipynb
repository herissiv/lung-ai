# %%
from ultralytics import YOLO
import torch

# %%
#Object detection

# !yolo task=detect mode=train model=yolov8m.pt data=/home/heris/data/RAW/YOLO_obj_dataset/data.yaml epochs=50 imgsz=512 translate = 0.0 scale = 0.1 fliplr = 0.0 hsv_h = 0.0 hsv_v = 0.0 hsv_s = 0.0 batch = 40 mosaic = 0
# Out:
# New https://pypi.org/project/ultralytics/8.0.209 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.13 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11163MiB)
# ...

# %%
# !pip install ultralytics==8.0.28
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.6/272.6 kB 1.9 MB/s eta 0:00:0000:0100:01
# ...
#   Obtaining dependency information for tensorboard>=2.4.1 from https://files.pythonhosted.org/packages/6e/0c/1059a6682cf2cc1fcc0d5327837b5672fe4f5574255fa5430d0a8ceb75e9/tensorboard-2.15.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for sentry-sdk from https://files.pythonhosted.org/packages/3a/f3/2790af9e769e62bef5d528ad66dbf0a1415d8177861056b0ae0b37cd6eed/sentry_sdk-1.35.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for absl-py>=0.4 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for grpcio>=1.48.2 from https://files.pythonhosted.org/packages/29/cc/e6883efbbcaa6570a0d2207ba53c796137f11293e47d11e2696f37b66811/grpcio-1.59.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...

# %%
# !yolo task=segment mode=train model=yolov8m-seg.pt data=/home/heris/data/RAW/YOLO_seg_dataset/data.yaml epochs=70 imgsz=512 batch = 32 device = 'cuda:0' translate = 0.0 scale = 0.1 fliplr = 0.0 hsv_h = 0.0 hsv_v = 0.0 hsv_s = 0.0 mosaic = 0
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.13 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11163MiB)
# ...

# %%
# !yolo task=segment mode=predict model=runs/segment/train2/weights/best.pt source = /home/heris/data/RAW/YOLO_seg_dataset/validation/images/image_1.3.6.1.4.1.14519.5.2.1.6279.6001.119104640879981165131898273686.png conf=0.70
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.13 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11163MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27222963 parameters, 0 gradients, 110.0 GFLOPs
#
# image 1/1 /home/heris/data/RAW/YOLO_seg_dataset/validation/images/image_1.3.6.1.4.1.14519.5.2.1.6279.6001.119104640879981165131898273686.png: 640x640 20.5ms
# Speed: 0.4ms pre-process, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict
